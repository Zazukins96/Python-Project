# %%
import numpy as np
import matplotlib.pyplot as plt
import seaborn as sns
import pandas as pd

# %%
df=pd.read_excel('myexcel.xlsx')
df
# Out:
#               Name            Team  Number Position  Age               Height  \
# 0    Avery Bradley  Boston Celtics       0       PG   25  2023-02-06 00:00:00
# 1      Jae Crowder  Boston Celtics      99       SF   25  2023-06-06 00:00:00
# 2     John Holland  Boston Celtics      30       SG   27  2023-05-06 00:00:00
# 3      R.J. Hunter  Boston Celtics      28       SG   22  2023-05-06 00:00:00
# 4    Jonas Jerebko  Boston Celtics       8       PF   29  2023-10-06 00:00:00
# ..             ...             ...     ...      ...  ...                  ...
# 453   Shelvin Mack       Utah Jazz       8       PG   26  2023-03-06 00:00:00
# 454      Raul Neto       Utah Jazz      25       PG   24  2023-01-06 00:00:00
# 455   Tibor Pleiss       Utah Jazz      21        C   26  2023-03-07 00:00:00
# 456    Jeff Withey       Utah Jazz      24        C   26                  7-0
# 457       Priyanka       Utah Jazz      34        C   25  2023-03-07 00:00:00
#
# ...

# %%
random_numbers=np.random.randint(150,181,size=len(df))
df['Height']=random_numbers
df
# Out:
#               Name            Team  Number Position  Age  Height  Weight  \
# 0    Avery Bradley  Boston Celtics       0       PG   25     171     180
# 1      Jae Crowder  Boston Celtics      99       SF   25     163     235
# 2     John Holland  Boston Celtics      30       SG   27     167     205
# 3      R.J. Hunter  Boston Celtics      28       SG   22     172     185
# 4    Jonas Jerebko  Boston Celtics       8       PF   29     177     231
# ..             ...             ...     ...      ...  ...     ...     ...
# 453   Shelvin Mack       Utah Jazz       8       PG   26     167     203
# 454      Raul Neto       Utah Jazz      25       PG   24     180     179
# 455   Tibor Pleiss       Utah Jazz      21        C   26     168     256
# 456    Jeff Withey       Utah Jazz      24        C   26     164     231
# 457       Priyanka       Utah Jazz      34        C   25     160     231
#
#                College     Salary
# 0                Texas  7730337.0
# ...

# %%
df.to_excel('pyproject.xlsx')

# %%
df=pd.read_excel('pyproject.xlsx')
df
# Out:
#      Unnamed: 0           Name            Team  Number Position  Age  Height  \
# 0             0  Avery Bradley  Boston Celtics       0       PG   25     171
# 1             1    Jae Crowder  Boston Celtics      99       SF   25     163
# 2             2   John Holland  Boston Celtics      30       SG   27     167
# 3             3    R.J. Hunter  Boston Celtics      28       SG   22     172
# 4             4  Jonas Jerebko  Boston Celtics       8       PF   29     177
# ..          ...            ...             ...     ...      ...  ...     ...
# 453         453   Shelvin Mack       Utah Jazz       8       PG   26     167
# 454         454      Raul Neto       Utah Jazz      25       PG   24     180
# 455         455   Tibor Pleiss       Utah Jazz      21        C   26     168
# 456         456    Jeff Withey       Utah Jazz      24        C   26     164
# 457         457       Priyanka       Utah Jazz      34        C   25     160
#
#      Weight            College     Salary
# ...

# %%
df.drop(columns='Unnamed: 0',inplace=True)
df
# Out:
#               Name            Team  Number Position  Age  Height  Weight  \
# 0    Avery Bradley  Boston Celtics       0       PG   25     171     180
# 1      Jae Crowder  Boston Celtics      99       SF   25     163     235
# 2     John Holland  Boston Celtics      30       SG   27     167     205
# 3      R.J. Hunter  Boston Celtics      28       SG   22     172     185
# 4    Jonas Jerebko  Boston Celtics       8       PF   29     177     231
# ..             ...             ...     ...      ...  ...     ...     ...
# 453   Shelvin Mack       Utah Jazz       8       PG   26     167     203
# 454      Raul Neto       Utah Jazz      25       PG   24     180     179
# 455   Tibor Pleiss       Utah Jazz      21        C   26     168     256
# 456    Jeff Withey       Utah Jazz      24        C   26     164     231
# 457       Priyanka       Utah Jazz      34        C   25     160     231
#
#                College     Salary
# 0                Texas  7730337.0
# ...

# %%
# 1.How many are there in each Team and the percentage splitting with respect to the total employees.
total_employees=df['Name'].count()
team_count=df['Team'].value_counts()

percentage_split=(team_count/total_employees)*100

team_details=pd.DataFrame({'TEAM':team_count.index,'NUMBER OF EMPLOYEES':team_count.values,'PERCENTAGE_SPLIT':percentage_split.values})
team_details
# Out:
#                       TEAM  NUMBER OF EMPLOYEES  PERCENTAGE_SPLIT
# 0     New Orleans Pelicans                   19          4.148472
# 1        Memphis Grizzlies                   18          3.930131
# 2                Utah Jazz                   16          3.493450
# 3          New York Knicks                   16          3.493450
# 4          Milwaukee Bucks                   16          3.493450
# 5            Brooklyn Nets                   15          3.275109
# 6   Portland Trail Blazers                   15          3.275109
# 7    Oklahoma City Thunder                   15          3.275109
# 8           Denver Nuggets                   15          3.275109
# 9       Washington Wizards                   15          3.275109
# 10              Miami Heat                   15          3.275109
# 11       Charlotte Hornets                   15          3.275109
# 12           Atlanta Hawks                   15          3.275109
# ...

# %%
### 2.segragate the employees w.r.t different positions.
# number of employees in each position
position_count=df['Position'].value_counts()
position_details=pd.DataFrame({'Position':position_count.index,'Number of employees':position_count})
print('Position Details')
print(position_details)
# Out:
# Position Details
#          Position  Number of employees
# Position
# SG             SG                  102
# PF             PF                  100
# PG             PG                   92
# SF             SF                   85
# C               C                   79

# %%
### 3.find from which age group most of the employees belongs to
age_data=df['Age'].value_counts()
age_details=pd.DataFrame({'Age':age_data.index,'Number of employees':age_data.values})
print('Age Details')
print(age_details)

# Histogram representation
plt.hist(df['Age'],bins=[0,10,20,30,40,50],edgecolor='orange')
plt.title('Distribution of Employees Across Age Groups')
plt.xlabel('Age Group')
plt.ylabel('Number of Employees')
plt.show()
# Out:
# Age Details
#     Age  Number of employees
# 0    24                   47
# 1    25                   46
# 2    27                   41
# 3    23                   41
# 4    26                   36
# 5    28                   31
# 6    30                   31
# 7    29                   28
# 8    22                   26
# 9    31                   22
# 10   20                   19
# 11   21                   19
# 12   33                   14
# 13   32                   13
# 14   34                   10
# 15   36                   10
# 16   35                    9
# 17   37                    4
# 18   38                    4
# 19   40                    3
# 20   39                    2
# 21   19                    2

# %%
### 4.find out under which team and position,spending in terms of salay is high.
max_salary_spending=df.groupby(['Team','Position'])['Salary'].sum().idxmax()
print(max_salary_spending)
# Out:
# ('Los Angeles Lakers', 'SF')

# %%
### 5.find if there is any correlation between age and salary,represent it visually
# scatterplot
sns.scatterplot(x='Age',y='Salary',hue='Position',data=df)
plt.xlabel('Age')
plt.ylabel('Salary')
plt.title('Age and salary correlation')
plt.show()
# heatmap
new=df[['Age','Salary']]
corr=new.corr()
sns.heatmap(corr,annot=True,cmap='cool')
plt.title('Correlaton Matrix')
plt.show()
print('The the correlation coefficient is:',df['Age'].corr(df['Salary']))
# Out:
# The the correlation coefficient is: 0.2140094122657097
